# %%
# Imports
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.data_loading import load_parquet, save_parquet
from src.feature_engineering import create_diphoton_features, calculate_diphoton_mass
from src.visualization import plot_signal_background, plot_invariant_mass
from src.utils import get_data_path

# %% [markdown]
# ## 1. İşlenmiş Veriyi Yükle

# %%
# Preprocessed veriler
# higgs = load_parquet(get_data_path('processed/higgs_processed.parquet'))
# qcd = load_parquet(get_data_path('processed/qcd_processed.parquet'))

# %% [markdown]
# ## 2. Feature Oluşturma

# %%
# Diphoton features
# higgs = create_diphoton_features(higgs)
# qcd = create_diphoton_features(qcd)

# %% [markdown]
# ## 3. Feature Dağılımları

# %%
# m_γγ karşılaştırması
# plot_signal_background(
#     higgs['m_yy'], qcd['m_yy'],
#     bins=80, range=(100, 160),
#     xlabel=r'$m_{\gamma\gamma}$ [GeV]',
#     title='Diphoton Invariant Mass'
# )
